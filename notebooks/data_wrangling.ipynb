# %%
import pandas as pd

# Load the id, name, and genres columns from the spotify data file into a DataFrame
tracks_df = pd.read_csv('../datasets/spotify_data.csv')

# Display the first few rows 
tracks_df.head()
# Out:
#    Unnamed: 0    artist_name        track_name                track_id  \
# 0           0     Jason Mraz   I Won't Give Up  53QF56cjZA9RTuuMZDrSA6
# 1           1     Jason Mraz  93 Million Miles  1s8tP3jP4GZcyHDsjvw218
# 2           2  Joshua Hyslop  Do Not Let Me Go  7BRCa8MPiyuvr2VU3O9W0F
# 3           3   Boyce Avenue          Fast Car  63wsZUhUZLlh1OsyrZq7sz
# 4           4   Andrew Belle  Sky's Still Blue  6nXIYClvJAfi6ujLiKqEq8
#
#    popularity  year     genre  danceability  energy  key  loudness  mode  \
# 0          68  2012  acoustic         0.483   0.303    4   -10.058     1
# 1          50  2012  acoustic         0.572   0.454    3   -10.286     1
# 2          57  2012  acoustic         0.409   0.234    3   -13.711     1
# 3          58  2012  acoustic         0.392   0.251   10    -9.845     1
# 4          54  2012  acoustic         0.430   0.791    6    -5.419     0
#
#    speechiness  acousticness  instrumentalness  liveness  valence    tempo  \
# ...

# %%
# Get a list of artists
artists = tracks_df['artist_name'].unique().tolist()

# Get the number of unique artists
len(artists)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 # Get a list of artists
# ----> 2 artists = tracks_df['artist_name'].unique().tolist()
#       4 # Get the number of unique artists
#       5 len(artists)
#
# NameError: name 'tracks_df' is not defined

# %%
# Get a list of genres
genres = tracks_df['genre'].unique()

# Output the list
genres
# Out:
# array(['acoustic', 'afrobeat', 'alt-rock', 'ambient', 'black-metal',
#        'blues', 'breakbeat', 'cantopop', 'chicago-house', 'chill',
#        'classical', 'club', 'comedy', 'country', 'dance', 'dancehall',
#        'death-metal', 'deep-house', 'detroit-techno', 'disco',
#        'drum-and-bass', 'dub', 'dubstep', 'edm', 'electro', 'electronic',
#        'emo', 'folk', 'forro', 'french', 'funk', 'garage', 'german',
#        'gospel', 'goth', 'grindcore', 'groove', 'guitar', 'hard-rock',
#        'hardcore', 'hardstyle', 'heavy-metal', 'hip-hop', 'house',
#        'indian', 'indie-pop', 'industrial', 'jazz', 'k-pop', 'metal',
#        'metalcore', 'minimal-techno', 'new-age', 'opera', 'party',
#        'piano', 'pop', 'pop-film', 'power-pop', 'progressive-house',
#        'psych-rock', 'punk', 'punk-rock', 'rock', 'rock-n-roll',
#        'romance', 'sad', 'salsa', 'samba', 'sertanejo', 'show-tunes',
#        'singer-songwriter', 'ska', 'sleep', 'songwriter', 'soul',
# ...

# %%
# Map genres to categories
genre_to_category = {
    'classical': 'Classical', 'new-age': 'Classical', 'opera': 'Classical', 'piano': 'Classical',
    'country': 'Country', 'forro': 'Country', 'sertanejo': 'Country',
    'ambient': 'Electronic', 'chill': 'Electronic', 'club': 'Electronic', 'dance': 'Electronic',
    'deep-house': 'Electronic', 'detroit-techno': 'Electronic', 'disco': 'Electronic',
    'drum-and-bass': 'Electronic', 'dub': 'Electronic', 'dubstep': 'Electronic', 'edm': 'Electronic',
    'electro': 'Electronic', 'electronic': 'Electronic', 'garage': 'Electronic',
    'hardstyle': 'Electronic', 'house': 'Electronic', 'minimal-techno': 'Electronic',
    'progressive-house': 'Electronic', 'techno': 'Electronic', 'trance': 'Electronic', 'trip-hop': 'Electronic',
    'acoustic': 'Folk', 'folk': 'Folk', 'singer-songwriter': 'Folk', 'songwriter': 'Folk',
    'gospel': 'Gospel',
    'afrobeat': 'Hip-Hop', 'hip-hop': 'Hip-Hop',
    'jazz': 'Jazz', 'blues': 'Jazz', 'funk': 'Jazz', 'soul': 'Jazz',
    'black-metal': 'Metal', 'death-metal': 'Metal', 'grindcore': 'Metal', 'hard-rock': 'Metal',
    'hardcore': 'Metal', 'heavy-metal': 'Metal', 'industrial': 'Metal', 'metal': 'Metal', 'metalcore': 'Metal',
    'comedy': 'Other', 'emo': 'Other', 'groove': 'Other', 'guitar': 'Other', 'party': 'Other',
    'power-pop': 'Other', 'romance': 'Other', 'sad': 'Other', 'sleep': 'Other', 'show-tunes': 'Other',
    'cantopop': 'Pop', 'indie-pop': 'Pop', 'pop': 'Pop', 'pop-film': 'Pop',
    'alt-rock': 'Rock', 'goth': 'Rock', 'psych-rock': 'Rock', 'punk': 'Rock',
    'punk-rock': 'Rock', 'rock': 'Rock', 'rock-n-roll': 'Rock',
    'french': 'World', 'german': 'World', 'indian': 'World', 'k-pop': 'World',
    'salsa': 'World', 'samba': 'World', 'spanish': 'World', 'swedish': 'World', 'tango': 'World'
}

# Add new column with mapped genres
tracks_df['new_genre'] = tracks_df['genre'].map(genre_to_category).fillna('Other')

# Display first few rows
tracks_df.head()
# Out:
#    Unnamed: 0    artist_name        track_name                track_id  \
# 0           0     Jason Mraz   I Won't Give Up  53QF56cjZA9RTuuMZDrSA6
# 1           1     Jason Mraz  93 Million Miles  1s8tP3jP4GZcyHDsjvw218
# 2           2  Joshua Hyslop  Do Not Let Me Go  7BRCa8MPiyuvr2VU3O9W0F
# 3           3   Boyce Avenue          Fast Car  63wsZUhUZLlh1OsyrZq7sz
# 4           4   Andrew Belle  Sky's Still Blue  6nXIYClvJAfi6ujLiKqEq8
#
#    popularity  year     genre  danceability  energy  key  ...  mode  \
# 0          68  2012  acoustic         0.483   0.303    4  ...     1
# 1          50  2012  acoustic         0.572   0.454    3  ...     1
# 2          57  2012  acoustic         0.409   0.234    3  ...     1
# 3          58  2012  acoustic         0.392   0.251   10  ...     1
# 4          54  2012  acoustic         0.430   0.791    6  ...     0
#
#    speechiness  acousticness  instrumentalness  liveness  valence    tempo  \
# ...

# %%
# Save the DataFrame to a new CSV file
tracks_df.to_csv('../static/dataset/track_data.csv', index=False)
